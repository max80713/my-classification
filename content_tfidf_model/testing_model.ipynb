# %% [markdown]
# - Import Packages

# %%
import json
import jieba
import pandas
import operator
import csv

# %% [markdown]
# - Load Data

# %%
keyword_tfidf_dict = json.load(open('keyword_tfidf_dict.json','r'))
training_data = json.load(open('accupass_events.json','r'))
testing_data = json.load(open('fb_events.json','r'))

# %% [markdown]
# - Predict Accupass Events

# %%
for data in training_data:
    class_names = []
    scores = []
    for class_name, keyword_tfidf in keyword_tfidf_dict.items():
        score = 0
        for keyword in data['content_cut']:
            if keyword in keyword_tfidf:
                score += keyword_tfidf[keyword]
        scores.append(score)
        class_names.append(class_name)
    
    data['predicted_class'] = class_names[scores.index(max(scores))]

# %% [markdown]
# - Predict Facebook Events

# %%
for data in testing_data:
    class_names = []
    scores = []
    for class_name, keyword_tfidf in keyword_tfidf_dict.items():
        score = 0
        for keyword in data['content_cut']:
            if keyword in keyword_tfidf:
                score += keyword_tfidf[keyword]
        scores.append(score)
        class_names.append(class_name)
    
    data['predicted_class'] = class_names[scores.index(max(scores))]
    data['predicted_score'] = max(scores)

json.dump(testing_data,open('facebook_events_classification_result.json','w'))

# %% [markdown]
# - Training Error

# %%
count = 0
for data in training_data:
    if data['predicted_class'] != data['class']:
        count += 1
print(count/len(training_data))
# Out:
# 0.5110716137154706

# %% [markdown]
# - Training Fusion Matrix

# %%
training_data_fusion_matrix = [[0 for i in range(13)] for i in range(13)]
class_names = []
for class_name in iter(keyword_tfidf_dict):
    class_names.append(class_name)
for data in training_data:
    training_data_fusion_matrix[class_names.index(data['predicted_class'])][class_names.index(data['class'])] += 1
training_data_fusion_matrix = pandas.DataFrame(training_data_fusion_matrix)
training_data_fusion_matrix.columns = class_names #actual_class
training_data_fusion_matrix.index = class_names #predicted_class
training_data_fusion_matrix
# Out:
#                fashion  entertainment  business  charity  health  arts  \
# fashion            287             78        63       18      14   170
# entertainment        1           1141        42       20       5   287
# business             2             72      2667       91      19   326
# charity              1             47        84      777      15   181
# health               2             50        22       56     685   176
# arts                 1            139        43       23       2  3523
# technology           1             63       335       18       0   133
# education            0             18       194       13       3    69
# sports               5            113        10       17      75    82
# photography          4             49        36       12       4   277
# food                 4            187        55       16      27   312
# travel               2            104       100       11       3   339
# other                2            191        51        2       5    62
#
#                technology  education  sports  photography  food  travel  other
# fashion                69        674      26           10    24      45    175
# entertainment         128        651      46            1     9      42     88
# business              219       3703      15            4    18      81    236
# charity                64        921      18            3    11      26    124
# health                 26        702      46            2    17      17     52
# arts                   32       1039       8            2     4      27     60
# technology           1328       2117      29            0     2      16    151
# education              21       5076       4            0     0      11     54
# sports                 18        493     705            3    10      19     27
# photography            58        562      21          447    10      44     43
# food                   51        759       9            1  1072      66     86
# travel                 62        731      14            2    12    1353     77
# other                  45        434       8            0    17      97    745

# %% [markdown]
# - Training F1-Score

# %%
training_data_f1_score = [[0 for i in range(13)] for i in range(3)]

class_names = []
for class_name in iter(keyword_tfidf_dict):
    class_names.append(class_name)

for i in range(13):
    training_data_f1_score[0][i] = training_data_fusion_matrix[class_names[i]][class_names[i]]/sum(training_data_fusion_matrix.ix[class_names[i]])
    training_data_f1_score[1][i] = training_data_fusion_matrix[class_names[i]][class_names[i]]/sum(training_data_fusion_matrix[class_names[i]])
    training_data_f1_score[2][i] = 2*training_data_f1_score[0][i]*training_data_f1_score[1][i]/(training_data_f1_score[0][i]+training_data_f1_score[1][i])
    
training_data_f1_score = pandas.DataFrame(training_data_f1_score)
training_data_f1_score.columns = class_names 
training_data_f1_score.index = ['precision', 'recall', 'f-score'] 

print(sum(training_data_f1_score.ix['f-score'])/len(training_data_f1_score.ix['f-score']))
# Out:
# 0.483158813969

# %% [markdown]
# - Select top-20 keywords for each class

# %%
keyword_tfidf_dict = json.load(open('keyword_tfidf_dict.json','r'))

for class_name, keyword_tfidf in keyword_tfidf_dict.items():
    keyword_tfidf_dict[class_name] = sorted(keyword_tfidf.items(), key=operator.itemgetter(1), reverse=True)

for class_name, keyword_tfidf_tuple in keyword_tfidf_dict.items():
    count = 0
    for keyword_tfidf_pair in keyword_tfidf_tuple:
        count += 1
        print(class_name+','+keyword_tfidf_pair[0]+','+str(format(keyword_tfidf_pair[1],'f'))) 
        if count == 20:
            break
# Out:
# health,側彎,0.000969
# health,脊椎,0.000380
# health,幹細胞,0.000298
# health,甩手,0.000294
# health,掌紋,0.000225
# health,嘜,0.000203
# health,清道夫,0.000168
# health,體位法,0.000148
# health,觸身,0.000128
# health,印可,0.000128
# health,易筋經,0.000124
# health,收款單,0.000118
# health,矯正,0.000117
# health,門診,0.000108
# health,骨盆,0.000096
# health,氣血,0.000091
# health,痠痛,0.000089
# health,物理治療師,0.000087
# health,痰,0.000086
# health,照顧,0.000085
# education,禧,0.000119
# education,陳光,0.000104
# education,貼布,0.000085
# education,課卷,0.000083
# education,心智圖,0.000080
# education,紮,0.000070
# education,心算,0.000048
# education,光明頂,0.000048
# education,轉職,0.000040
# education,談判,0.000040
# education,聖杯,0.000039
# education,空勤,0.000038
# education,付清了,0.000037
# education,技術分析,0.000037
# education,中華工商,0.000036
# education,操盤,0.000035
# education,外匯,0.000035
# education,勝率,0.000032
# education,流量,0.000032
# education,加薪,0.000031
# fashion,香水,0.001032
# fashion,試穿,0.000382
# fashion,時裝展,0.000372
# fashion,過肩,0.000366
# fashion,穿起來,0.000360
# fashion,模子,0.000344
# fashion,穿到,0.000336
# fashion,上流人士,0.000301
# fashion,後顧,0.000301
# fashion,蠻像,0.000301
# fashion,最省,0.000264
# fashion,大量生產,0.000224
# fashion,宗教上,0.000219
# fashion,分群,0.000219
# fashion,鬼使神差,0.000196
# fashion,促發,0.000179
# fashion,冤枉錢,0.000179
# fashion,限度,0.000172
# fashion,規模經濟,0.000172
# fashion,主調,0.000172
# travel,紅包場,0.000112
# travel,度假,0.000111
# travel,亂滾,0.000091
# travel,簽證,0.000075
# travel,歌廳,0.000073
# travel,美濃,0.000065
# travel,南庄,0.000065
# travel,導覽員,0.000064
# travel,背包客,0.000060
# travel,集集,0.000059
# travel,搭便車,0.000058
# travel,滑雪,0.000057
# travel,伊朗,0.000057
# travel,賓果,0.000057
# travel,金質,0.000056
# travel,打工,0.000054
# travel,單身,0.000053
# travel,環遊世界,0.000053
# travel,露營,0.000053
# travel,板鴨,0.000051
# other,槍手,0.000195
# other,友派,0.000149
# other,以上學歷,0.000138
# other,軍公教,0.000097
# other,聯誼,0.000091
# other,婚友社,0.000089
# other,交點,0.000082
# other,六尾,0.000077
# other,空勤,0.000076
# other,圓桌會議,0.000067
# other,魔方,0.000066
# other,東協,0.000065
# other,中點,0.000061
# other,雅緻,0.000058
# other,年次,0.000057
# other,單身,0.000056
# other,襯衫,0.000053
# other,考場,0.000052
# other,訂製,0.000050
# other,造假,0.000050
# entertainment,高雄港,0.000170
# entertainment,密室,0.000139
# entertainment,乘客,0.000111
# entertainment,遊戲,0.000110
# entertainment,馬沙溝,0.000099
# entertainment,登船,0.000090
# entertainment,小羊,0.000083
# entertainment,潘朵拉,0.000083
# entertainment,開航,0.000082
# entertainment,犄角,0.000081
# entertainment,逃脫,0.000081
# entertainment,電競,0.000078
# entertainment,絕對零度,0.000077
# entertainment,解謎,0.000075
# entertainment,謎題,0.000075
# entertainment,暈船,0.000071
# entertainment,奇案,0.000068
# entertainment,航班,0.000067
# entertainment,野狼,0.000059
# entertainment,台港澳,0.000058
# business,瓦舍,0.005656
# business,夢園,0.001237
# business,築,0.000651
# business,難點,0.000480
# business,優先權,0.000432
# business,一去不回,0.000413
# business,功成身退,0.000413
# business,天下沒有白吃的午餐,0.000373
# business,算帳,0.000372
# business,白吃,0.000372
# business,無目,0.000372
# business,內鬥,0.000372
# business,聊著,0.000345
# business,法拍,0.000342
# business,開張,0.000332
# business,依約,0.000326
# business,缺錢,0.000325
# business,定時間,0.000325
# business,貸,0.000324
# business,車貸,0.000324
# technology,槓,0.000178
# technology,物聯網,0.000108
# technology,交點,0.000104
# technology,機器人,0.000090
# technology,開發者,0.000089
# technology,電阻,0.000082
# technology,旋翼,0.000081
# technology,程式,0.000078
# technology,開發,0.000072
# technology,飛行器,0.000069
# technology,聯網,0.000064
# technology,微軟,0.000061
# technology,電路,0.000059
# technology,魅,0.000056
# technology,套件,0.000055
# technology,電路板,0.000055
# technology,模組,0.000052
# technology,程式語言,0.000051
# technology,搭訕,0.000046
# technology,比特幣,0.000045
# photography,測光,0.000834
# photography,快門,0.000495
# photography,禎,0.000467
# photography,外拍,0.000360
# photography,相機,0.000324
# photography,光圈,0.000318
# photography,人像,0.000204
# photography,閃燈,0.000202
# photography,對焦,0.000192
# photography,多燈,0.000186
# photography,攝影課,0.000183
# photography,攝影社,0.000179
# photography,白平衡,0.000179
# photography,景深,0.000171
# photography,單眼相機,0.000161
# photography,夜拍,0.000136
# photography,車軌,0.000136
# photography,周三,0.000135
# photography,攝影棚,0.000127
# photography,上堂,0.000119
# charity,探索者,0.000124
# charity,黑松,0.000122
# charity,手札,0.000122
# charity,糙,0.000120
# charity,米餅,0.000097
# charity,掛圖,0.000097
# charity,軟墊,0.000092
# charity,志工,0.000091
# charity,銀髮,0.000072
# charity,日托,0.000067
# charity,蹲點,0.000067
# charity,補位,0.000063
# charity,原聲,0.000063
# charity,兔,0.000051
# charity,行動劇,0.000048
# charity,圍兜,0.000048
# charity,社會局,0.000047
# charity,超心理學,0.000047
# charity,慢飛天使,0.000046
# charity,放生,0.000046
# sports,救生,0.000603
# sports,滾筒,0.000436
# sports,瑜伽,0.000240
# sports,救生員,0.000199
# sports,徒手,0.000174
# sports,焦躁,0.000163
# sports,墊上,0.000157
# sports,水中,0.000140
# sports,體位法,0.000136
# sports,體適能,0.000131
# sports,有氧,0.000129
# sports,啵,0.000122
# sports,紮,0.000122
# sports,貼布,0.000106
# sports,腰酸背痛,0.000104
# sports,泰拳,0.000103
# sports,護身,0.000095
# sports,酸痛,0.000093
# sports,背部,0.000093
# sports,裁判,0.000093
# arts,偶戲,0.000072
# arts,影展,0.000067
# arts,當代藝術,0.000060
# arts,紅樓,0.000058
# arts,鋼琴,0.000054
# arts,演出,0.000052
# arts,字型,0.000046
# arts,個展,0.000042
# arts,長笛,0.000042
# arts,劇團,0.000040
# arts,獨奏,0.000040
# arts,放映,0.000038
# arts,漢字,0.000037
# arts,版畫,0.000036
# arts,探戈,0.000034
# arts,周道,0.000033
# arts,音樂劇,0.000032
# arts,民謠,0.000032
# arts,寧波,0.000031
# arts,畫畫,0.000031
# food,把完,0.000283
# food,糖霜,0.000261
# food,魚翅,0.000243
# food,掌櫃,0.000170
# food,圍裙,0.000165
# food,柯達,0.000161
# food,連通,0.000158
# food,葡萄酒,0.000138
# food,麵團,0.000137
# food,耽誤,0.000100
# food,或早,0.000100
# food,牛肉,0.000096
# food,收涎,0.000089
# food,紙盒,0.000083
# food,酒莊,0.000082
# food,圍坐,0.000075
# food,世界文化,0.000074
# food,牛腱,0.000069
# food,空置,0.000066
# food,醬汁,0.000066

# %% [markdown]
# - Sort and select results by probability for each class

# %%
results = json.load(open('facebook_events_classification_result.json','r'))

classified_results = {}
for result in results:
    class_name = result['predicted_class']
    if class_name not in classified_results:
        classified_results[class_name] = []
    classified_results[class_name].append(result)

for class_name, events in classified_results.items():
    classified_results[class_name].sort(key=lambda x:x['predicted_score'], reverse=True)

f = open("top_100_events_by_class.csv", "w")

for class_name, events in classified_results.items():
    count = 0
    print(class_name, file=f, end ='')
    for event in events:
        count += 1
        print(','+event['id'], file=f, end ='') 
        if count == 100:
            break
    print('',file=f)

f.close()

# %% [markdown]
# - View result

# %%
events = json.load(open("fb_original_data.txt", "r"))

result = {}
for line in open("top_100_events_by_class.csv", "r"):
    class_events = line.strip('\n').split(',')
    result[class_events[0]] = []
    for i in range(1,11): 
        for event in events:
            if class_events[i] == event['id']:
                result[class_events[0]].append(event['name'])

for i,j in result.items():
    print(i)
    for jj in j:
        print(jj)
# Out:
# fashion
# 3/31前【L’AROMA滿額3000元，贈送生命數字基礎解析】
# 信義誠品國際香水聯合特賣
# 品香氛.玩調香
# 品香氛.玩調香
# Satin美睫美學館-中壢店 4月各項優惠獨特方案來囉
# Satin美睫美學館 4月各項優惠獨特方案來囉
# LFP:單一核心配方香水創作活動
# 時尚巴黎【讓你愛上山茶花】
# ❤️Satin美睫美學館3月超質優惠來囉❤️ 慶祝林口店、中壢店週年慶
# ★拍照上傳穿搭照 分享你的必勝LOOK!
# entertainment
# 神奇的蛻變遊戲同樂會
# 貓腳印 x TRPG貓貓大冒險 x 雙周團
# 貓腳印 x TRPG貓貓大冒險 x 雙周團
# 貓腳印 x TRPG貓貓大冒險 x 雙周團
# 貓腳印 x TRPG貓貓大冒險 x 雙周團
# 新溫羅汀實境遊戲－城市邊陲的遁逃者
# 2016 麗星郵輪夏日趣 ( &兔奴 )
# 好神奇的桌遊~【蛻變遊戲】試玩/同樂會
# 2016/05/24【心靈魔法遊戲】曾宇君 溝通師
# 沙漠風暴雷射射擊
# business
# 【藝文活動】相聲瓦舍-賣橘子的
# 賣橘子的
# 賣橘子的
# 你的我的螢火蟲日記
# 台灣兒童巴西戰舞Capoeira國際課程與晉級活動
# 【河川修復—全紀錄分享會】—｜日式宿舍的建築ID｜
# 心築愛樂合唱團-音悅有愛慈善音樂會
# 布條訂購4/1-4/30
# 跨境電商交易風險─金流/物流/稅務精算獲利／萬幼筠
# 跨境電商在美國─如何在Amazon上賣爆紅商品／Anfernee
# charity
# 「2016 星星相惜讓愛走動」
# Holiday ya二手市集 愛心義賣jumble sale跳蚤市場x古著x身心靈占卜x Live演唱 x 手作甜點..一起幫助流浪兔&街友!20160814暑假再會場Charity Flea Market
# Holiday ya二手市集 愛心義賣jumble sale跳蚤市場 x 古著vintage x占卜x Live演唱 x 手作甜點..一起幫助流浪兔&街友!20160724暑假首場Charity Flea Market
# Holiday ya二手市集 愛心義賣jumble sale跳蚤市場 x 毛孩溝通 x占卜 x Live演唱 x 手作甜點..一起幫助流浪兔&街友!20160409上半年最後一場Charity Flea Market
# T12睦育春嬉遊
# 巨量天燈垃圾！平溪淨山活動_4/3（日）9am
# 中華長跑協會志工【特殊訓練】Part II (3/31 19:00 ~ 21:00)
# 中華長跑協會志工【特殊訓練】Part I (3/29 19:00 ~ 21:00)
# 04/17(日)台北市寧瑪白玉大圓滿佛學會「長壽放生法會」
# 5/14(週六)關愛之家~關愛之旅+捐款捐物
# education
# 劉必榮教授談判兵法菁英特訓營
# 2015年劉必榮教授談判兵法菁英特訓營
# 2016心智圖一日工作坊報名表--新竹班:5/22，台北班:4/24、6/19
# N.115場跨產業沙龍：全台最大每週跨界交流論壇（每週三天地人文創）
# 生命數字學 (初階、進階)
# 「圖像，讓溝通更有效率！」-【資訊設計x視覺圖像】實戰工作坊
# 一本 讀書會 4/16講座、5/9例會
# 解密「#存在感暴增術」！超實用粉絲頁經營技巧大公開！
# 台北站 - MMI有錢人想的不一樣全球巡回三天密集課程 The Millionaire Mind Intensive
# 【張耀宗老師總裁神機妙算商戰營運班】
# health
# 2016年度牙醫助理基礎認證課程
# New ✿ 3/31 (周四) 黃靜心: 獅子心靜心(太陽神經叢)
# 來自印度 新意識靜心 系列-彩虹靜心系
# 來自印度 新意識靜心 系列-彩虹靜心系
# 健康美麗窈窕專案活動最高折扣6折起
# 愛米拉 臼井靈氣一階證書課程
# 養心殿：在正念中 長養身與心的輕安自在--六日正念工作坊
# 養生主靈性按摩 第154期 (廈門)
# ░【彩虹祝福按摩培訓-海底輪-紅色大地 深入小班制-限8位】░
# 大天使綜合能量療法初中高階授證課程(Integrated Energy Therapy®)
# arts
# 2016 小地方 Jazz Festival
# 手風琴體驗班 / 班多鈕&手風琴(鍵盤/按鈕)
# 爵士吉他生存手冊講座與演出（高雄Madker Cafe）
# 「來吧，世界，我敬你！」─ 貝多芬第九號交響曲《合唱》
# Tango Emocional Ensemble @Tanguísimo 經典舞會 Classic Milonga
# 從技巧、樂感及藝術性論俄國鋼琴表演藝術
# 20160327啊嘶現場樂團舞會X愛探戈樂團
# 【亞洲唯一】最後的世界巡演 ─ 奧地利國寶大師 巴杜拉-史寇達鋼琴獨奏會
# 西班牙鞭擊Big 4 Angelus Apatrida Live in Taipei 鞭擊大屠殺五
# 3/31陰府門重金屬中毒營[推廣重金屬音樂文化系列講座] -最終場
# food
# 春光乍鮮 蠢蠢慾動-葡萄酒與日本料理的怦然心動
# 056(已額滿開放後補)美國膜拜酒先鋒 方濟酒莊+金芬教父酒莊
# 江井ヶ嶋酒造（EIGASHIMA SHUZO）/Akashi whisky seminar
# 上課打卡拿好康~
# 跟著澳客一起喝(三)西澳地區 (額滿)
# 跟著澳客一起喝(二)
# 年度西班牙Valserrano 沙雷諾谷酒莊代表來台品鑒會（花蓮站）
# 059 (已額滿開放後補)義大利MASI 酒莊- WS年度百大No.8品飲會
# 精釀啤酒品嚐暨實作工作坊 Workshop II
# 精釀啤酒品嚐暨實作工作坊 Workshop I
# other
# 與艾草一起過端午！-香巷綠園·藝治療-
# 單身聯誼活動
# 康聯講堂：康輔x生活
# 奉旨為祖先及全國母親祈福延壽萬人大法會
# 高雄『體貼紳士170 vs 窈窕淑女』愛你一世未婚聯誼
# 世新大學 青澀影展《工具人Tool Man》演員徵選
# ♡Friday Night真愛鄰距離♡ 軍公教男孩 + 台北愛情故事
# 【圖解象徵占星學】宇宙象徵占星學
# 新竹『~❤ 幸福來找茶 ❤~約會我和你』未婚聯誼
# 台北文山扶輪青年服務團 二十五週年團慶暨授證典禮
# sports
# 美國瑜伽師資認證課程 RYT200 with Rachel Tsai
# IRIA ASIA國際搜救教練聯盟急流救生Rescue1訓練課程（香港區）
# 2016 Janet Lau 90小時瑜伽生活模組師資班 - 師生本是相連 RYT 200/300/500
# 太陽的後裔(대양의후예) 金利眩 (김이현) 老師Priya vinyasa 50小時師資培訓
# AFAA 美國有氧體適能協會 Mat Science師資養成暨檢定班（台中場）
# 《藝術與瑜伽療癒師培訓》
# 空中流動瑜伽師資培訓課程首次高雄場
# 4月30到5月01日(救生員初級班)
# BLACKROLL®按摩滾筒國際認證課 [05/15]
# Mr.Roller 滾筒自我肌筋膜放鬆技術（SMaRT）實務操作課程－4/30 台北場
# photography
# 半線攝影學會 105年攝影班
# 晒機市集 第三回 (老相機二手市集 台北當代藝術館場)
# 最牛的三軸穩定器相機 Kd100-4k1 初階版 Kd100-4k2 進階版 出租中 現在訂4/14可正常交貨
# 閃燈實戰運用 專題攝影研習班
# 『逗陣來翕相』~第2期攝癮超人白天風景班
# 4/17早上 新生代甜美高中生阿涵 青田街團拍
# (北投)(婚紗團)5/09(ㄧ)(午場) 陽明山蒙馬特莊園 歐式宮廷婚紗外拍-172cm金髮美女Kimberlly陳怡伶(有棚燈外拍燈觸閃)
# Mio’s Studio攝影講座三部曲 板橋場
# 『逗陣來翕相』~第1期攝癮超人暑期晨昏班
# 《傑克亂拍》攝影基礎夜間班(2016/5/10開課)
# technology
# 台灣創新服務一條龍(高雄場)
# N.117場跨產業沙龍：全台最大每週跨界交流論壇（每週三天地人文創）
# 【工作營】ATOM 2.0 3D印表機 組裝工作營 (Level3) 4/16~17 9~18 共 16hr
# 彩虹牧場翻轉機器人教室週六班_標準階第七期
# Yahoo Mobile Developer Conference 雅虎行動開發者大會
# 【創業小聚#64】掌握溝通技巧，打破工程師與設計師的平行時空！
# App台槓 三月份聚會 - PULO找師傅 - 資金找政府、裝潢找師傅
# App台槓 四月份聚會 - 你的App安全嗎？ - 台灣App遭駭案例故事分享
# 天地人學堂：網站 企劃及開發管理實戰課程（不是工程師也能一次學會網站企劃與發包 網站 開發能力）
# 03/20~04/24機器手臂自己做(3D列印實務應用)
# travel
# 2016年08月15日~08月21日本富士山、上高地、 立山黑部七日遊
# 2016系列01左堆客家及林邊溪流域多元族群人文及地理環境探索之旅(一日福斯9人座)
# 富士山登峰之旅(來去富士住一晚)報名2/28止
# ★【鐵路玩家】5月19日出發~台鐵觀光環島商務專列
# 遇見夢幻藍眼淚～南北竿＋東莒三日風情遊
# 車環島壯遊_2016/03/19 - 03/27
# 2016年 烏岩角露營溯海+獨木舟自然生態探索總網頁
# 0604-05日 2016烏岩角露營溯海+獨木舟活動
# 0903-04日2016年 烏岩角露營溯海+獨木舟活動
# 0611-12日2016年 烏岩角露營溯海+獨木舟活動

# %%
results = json.load(open('facebook_events_classification_result.json','r'))

# %%
events = json.load(open("fb_original_data.txt", "r"))

# %%
len(events)
# Out:
# 12786

# %%
len(results)
# Out:
# 12786

# %%
for event in events:
    flag = 0
    for result in results:
        if event['id'] == result['id']:            
            event['predicted_class'] = result['predicted_class']
            event['predicted_score'] = result['predicted_score']
            flag = 1
            break
    if flag == 0:
        print(event['id'])

# %%
json.dump(events,open('classified_facebook_events.json','w'))

# %%
for data in testing_data:
    del data['content_cut']

# %%
f = open('facebook_events_classification_result.csv','w')
for data in testing_data:
    print(data['id']+','+data['predicted_class']+','+str(format(data['predicted_score'],'f')), file=f)

# %%
f2 = json.load(open('fb_original_data.txt', 'r'))

# %%
f2[0]['description']
# Out:
# '彰商校慶肆壹六\n\n蓊鬱的校園理\n藏著一個可以High翻屋頂的班級\n它們\n隱藏著\n笑聲可以從明德樓傳去後操場\n笑點比死海還低\n因笑而爆肺 每天要換肺數十顆\n笑梗比辭海還多\n智商比聖母峰還高\n的高人\n這個班級\n有堪比劉以豪、陶敏敏的男女神(經病)\n打LOL跟統神相著稱的陳嘉航\n射速三秒的孔子後代\n吼聲可以從基隆傳到鵝鑾鼻的大聲公\n倉鼠 土撥鼠 馬兒 章魚 金魚什麼動物通通有\n\n世上最令人意想不到的菜單\n鮮香粉嫩的波多奶\n用歌名詮釋的神秘飲品\n野豬騎士載著仲基進入您的胃\n資一1\n將使用奇特的魔力\n去征服您的味蕾\n\n彰商\n資一1\n歡 迎 你！'

# %%
f = open('top_100_keywords_for_each_class.csv', 'r')
for line in f.readlines():
    keywords = line.strip('\n').split(',')
    print(keywords[0])
    for i in range(1,21):
        print(keywords[i]+':', end='')
        count = 0 
        for event in f2:
            if keywords[i] in event['description']:
                count += 1
        print(count)
f.close()
# Out:
# health
# 側彎:6
# 脊椎:43
# 幹細胞:2
# 甩手:2
# 掌紋:0
# 嘜:1
# 清道夫:0
# 體位法:62
# 印可:1
# 觸身:6
# 易筋經:2
# 收款單:0
# 矯正:20
# 門診:5
# 骨盆:20
# 氣血:7
# 痠痛:14
# 物理治療師:26
# 痰:3
# 照顧:183
# sports
# 救生:52
# 滾筒:11
# 瑜伽:85
# 救生員:11
# 徒手:20
# 焦躁:7
# 墊上:6
# 水中:40
# 體位法:62
# 體適能:24
# 有氧:33
# 啵:4
# 紮:121
# 貼布:9
# 腰酸背痛:3
# 泰拳:5
# 護身:12
# 酸痛:9
# 背部:25
# 裁判:72
# other
# 槍手:0
# 友派:1
# 以上學歷:11
# 軍公教:8
# 聯誼:86
# 婚友社:2
# 交點:8
# 六尾:0
# 空勤:0
# 圓桌會議:1
# 魔方:3
# 東協:11
# 中點:19
# 雅緻:7
# 年次:43
# 單身:67
# 襯衫:20
# 考場:3
# 訂製:22
# 公廁:1
# technology
# 槓:15
# 物聯網:9
# 交點:8
# 機器人:25
# 開發者:8
# 電阻:1
# 旋翼:2
# 程式:57
# 開發:193
# 飛行器:0
# 聯網:21
# 微軟:12
# 電路:8
# 魅:221
# 套件:9
# 電路板:3
# 模組:19
# 程式語言:2
# 搭訕:2
# 比特幣:1
# food
# 把完:1
# 糖霜:34
# 魚翅:0
# 掌櫃:4
# 圍裙:32
# 柯達:1
# 連通:2
# 葡萄酒:78
# 麵團:12
# 耽誤:23
# 或早:3
# 牛肉:37
# 收涎:7
# 紙盒:7
# 酒莊:53
# 圍坐:3
# 世界文化:7
# 牛腱:0
# 空置:0
# 醬汁:10
# fashion
# 香水:28
# 試穿:9
# 時裝展:0
# 過肩:0
# 穿起來:0
# 模子:3
# 穿到:0
# 上流人士:1
# 蠻像:0
# 後顧:3
# 最省:3
# 大量生產:0
# 分群:0
# 宗教上:0
# 鬼使神差:0
# 冤枉錢:1
# 促發:0
# 主調:0
# 規模經濟:0
# 限度:5
# business
# 瓦舍:4
# 夢園:0
# 築:253
# 難點:0
# 優先權:1
# 一去不回:0
# 功成身退:0
# 天下沒有白吃的午餐:0
# 無目:6
# 白吃:3
# 內鬥:1
# 算帳:0
# 聊著:3
# 法拍:1
# 開張:10
# 依約:1
# 缺錢:3
# 定時間:44
# 貸:18
# 車貸:1
# charity
# 探索者:4
# 黑松:4
# 手札:6
# 糙:9
# 米餅:1
# 掛圖:0
# 軟墊:3
# 志工:188
# 銀髮:12
# 日托:1
# 蹲點:2
# 補位:3
# 原聲:12
# 兔:107
# 行動劇:2
# 圍兜:22
# 社會局:13
# 超心理學:0
# 慢飛天使:0
# 放生:9
# photography
# 測光:3
# 快門:43
# 禎:33
# 外拍:434
# 相機:240
# 光圈:10
# 人像:87
# 閃燈:128
# 對焦:5
# 多燈:1
# 攝影課:9
# 白平衡:22
# 攝影社:34
# 景深:2
# 單眼相機:5
# 夜拍:9
# 車軌:6
# 周三:40
# 攝影棚:108
# 上堂:1
# travel
# 紅包場:0
# 度假:45
# 亂滾:0
# 簽證:15
# 歌廳:1
# 美濃:33
# 南庄:10
# 導覽員:13
# 背包客:42
# 集集:7
# 搭便車:14
# 滑雪:11
# 伊朗:6
# 賓果:2
# 金質:3
# 打工:57
# 單身:67
# 環遊世界:20
# 露營:77
# 板鴨:0
# arts
# 偶戲:13
# 影展:111
# 當代藝術:51
# 紅樓:17
# 鋼琴:231
# 演出:741
# 字型:8
# 個展:108
# 長笛:45
# 劇團:78
# 獨奏:135
# 放映:71
# 漢字:7
# 版畫:16
# 探戈:53
# 周道:0
# 音樂劇:25
# 民謠:52
# 寧波:2
# 畫畫:49
# entertainment
# 高雄港:5
# 密室:8
# 乘客:13
# 遊戲:403
# 馬沙溝:1
# 登船:7
# 小羊:6
# 潘朵拉:4
# 開航:3
# 犄角:0
# 逃脫:12
# 電競:3
# 絕對零度:0
# 解謎:1
# 謎題:4
# 暈船:19
# 奇案:0
# 航班:15
# 野狼:2
# 台港澳:0
# education
# 禧:15
# 陳光:2
# 貼布:9
# 課卷:0
# 心智圖:2
# 紮:121
# 心算:1
# 光明頂:1
# 轉職:10
# 談判:15
# 聖杯:3
# 空勤:0
# 付清了:1
# 技術分析:2
# 中華工商:0
# 操盤:7
# 外匯:0
# 勝率:6
# 流量:18
# 加薪:6
